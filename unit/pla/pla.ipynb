# %% [markdown]
# # Perceptron Learning Algorithm (PLA) 演算法
#
# 利用以下準備好的工具，實作 PLA 演算法，演算法細節可以參考 Youtube 的林軒田老師的[機器學習基石](https://www.youtube.com/watch?v=WlpF1Phkv28&list=PLXVfgk9fNX2I7tB6oIINGBmW50rrmFTqf&index=6)影片。
#
# # 二維 PLA 展示
#
# 執行下方程式碼可以初始化一個二維的示範 PLA 模型：

# %%
import sys
sys.path.append('.prepared')
import pla as prepared

prepared.reset()

# %% [markdown]
# 從下方的 for 迴圈可以看到該 PLA 模型前五次迭代的過程，一步步更新向量達到分離的目的。
# 收斂後可以執行 reset() 重置模型狀態。

# %%
for i in range(5):
    prepared.update()
    prepared.plot()

# %% [markdown]
# ## prepared.demo_pla()
#
# 完整的 PLA 展示，目標就是開發出同樣功能的函式，並使用自己開發的 `pla()` 取代。詳見下方[動手做](#動手做)的程式碼範例。
#
# ## prepared.reset()
#
# 重置示範 PLA 模型的狀態。詳見上方[二維PLA 展示](#二維-PLA-展示)的程式碼範例。
#
# ## prepared.update()
#
# 更新並繪製示範 PLA 模型。詳見上方[二維 PLA 展示](#二維-PLA-展示)的程式碼範例。
#
# # 動手做
#
# 請完成 `pla()`，並用其取代 `prepared.demo_pla()`，使其輸出和 demo_pla 相同的結果。
#
# ----
# 貼心小提醒:
# 1. 務必從 pla.dat 最上方的資料， **從頭開始** 逐步更新向量，否則會導致答案的不一致。

# %%
import sys
sys.path.append('.prepared')
import pla as prepared

def pla():
    # TODO: start coding here... 
    # the first thing is to read `pla.dat`
    f  = open('./pla.dat', 'r')
    print(f.read())
    
prepared.demo_pla()
# TODO: comment the above line and un-comment the below line once you finish `pla()`
# pla()
# Out:
# #45 [-3.          3.08414355 -1.58308104  2.39130508  4.52876345]
