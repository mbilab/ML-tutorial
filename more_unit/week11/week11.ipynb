# %% [markdown]
# ## Data detail
# - Data from: /home/mlb2017/res/phosphosite
# - Data description:
#     - Train
#         - trainX.npy : 10518 samples, each sample has 342 features
#         - trainY.npy : 5259 positive, 5259 negative
#         - train_data : 4 columns
#              - <font color = 'red'>** is phophorylation site or not (yes : 1, no : 0) **</font>
#              - <font color = 'red'>** protein name **</font>
#              - <font color = 'red'>** site sequence (length: 19), the middle one is the possible phosphorylation site (T) **</font>
#              - <font color = 'red'>** the possible phosphorylation-site's (T) position in protein sequence **</font>
#
#     - Validation
#         - validationX.npy :  48221 samples, each sample has 342 features
#         - validationY.npy :  494 positive,  47727 negative
#         - validation_data : 4 columns, same as train_data
#
#     - Test (not released now)
#         - testX.npy :  48220 samples, each sample has 342 features
#         - testY.npy :  493 positive,  47727 negative
#         - test_data : 4 columns, same as train_data
# - features
#     - Overlapping properties(190)
#     - Shannon entropy(19)
#     - Relative entropy(19)
#     - Second Structure(57)
#     - Protein Disorder(38)
#     - Accessible surface area(19)
#
# ## Today's mission
# > According to the protein name(second columns), write a crawler to get a protein sequence length.
#
# > [UniProt](http://www.uniprot.org/): search protein name on the website and parse the information you want.
#
# > e.g. protein name: Q9NZQ3
#
# ![%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202017-11-30%20%E4%B8%8A%E5%8D%889.17.35.jpg](attachment:%E8%9E%A2%E5%B9%95%E5%BF%AB%E7%85%A7%202017-11-30%20%E4%B8%8A%E5%8D%889.17.35.jpg)

# %%
## Code here ## 
import requests
from bs4 import BeautifulSoup

protein_name = 'Q9NZQ3'

# %%
print(sequence_len)
# Out:
# 722
